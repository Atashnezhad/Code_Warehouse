# %%
from pathlib import Path

class DisplayablePath(object):
    display_filename_prefix_middle = '├──'
    display_filename_prefix_last = '└──'
    display_parent_prefix_middle = '    '
    display_parent_prefix_last = '│   '

    def __init__(self, path, parent_path, is_last):
        self.path = Path(str(path))
        self.parent = parent_path
        self.is_last = is_last
        if self.parent:
            self.depth = self.parent.depth + 1
        else:
            self.depth = 0

    @property
    def displayname(self):
        if self.path.is_dir():
            return self.path.name + '/'
        return self.path.name

    @classmethod
    def make_tree(cls, root, parent=None, is_last=False, criteria=None):
        root = Path(str(root))
        criteria = criteria or cls._default_criteria

        displayable_root = cls(root, parent, is_last)
        yield displayable_root

        children = sorted(list(path
                               for path in root.iterdir()
                               if criteria(path)),
                          key=lambda s: str(s).lower())
        count = 1
        for path in children:
            is_last = count == len(children)
            if path.is_dir():
                yield from cls.make_tree(path,
                                         parent=displayable_root,
                                         is_last=is_last,
                                         criteria=criteria)
            else:
                yield cls(path, displayable_root, is_last)
            count += 1

    @classmethod
    def _default_criteria(cls, path):
        return True

    @property
    def displayname(self):
        if self.path.is_dir():
            return self.path.name + '/'
        return self.path.name

    def displayable(self):
        if self.parent is None:
            return self.displayname

        _filename_prefix = (self.display_filename_prefix_last
                            if self.is_last
                            else self.display_filename_prefix_middle)

        parts = ['{!s} {!s}'.format(_filename_prefix,
                                    self.displayname)]

        parent = self.parent
        while parent and parent.parent is not None:
            parts.append(self.display_parent_prefix_middle
                         if parent.is_last
                         else self.display_parent_prefix_last)
            parent = parent.parent

        return ''.join(reversed(parts))

# %%
paths = DisplayablePath.make_tree(Path('../Code_Warehouse/'))
for path in paths:
    print(path.displayable())
# Out:
# Code_Warehouse/
# ├── .DS_Store
# ├── .git/
# │   ├── branches/
# │   ├── COMMIT_EDITMSG
# │   ├── config
# │   ├── description
# │   ├── FETCH_HEAD
# │   ├── HEAD
# │   ├── hooks/
# │   │   ├── applypatch-msg.sample
# │   │   ├── commit-msg.sample
# │   │   ├── fsmonitor-watchman.sample
# │   │   ├── post-update.sample
# │   │   ├── pre-applypatch.sample
# │   │   ├── pre-commit.sample
# │   │   ├── pre-push.sample
# │   │   ├── pre-rebase.sample
# │   │   ├── pre-receive.sample
# │   │   ├── prepare-commit-msg.sample
# │   │   └── update.sample
# │   ├── index
# │   ├── info/
# │   │   └── exclude
# │   ├── logs/
# │   │   ├── HEAD
# │   │   └── refs/
# │   │       ├── heads/
# │   │       │   └── master
# │   │       └── remotes/
# │   │           └── origin/
# │   │               ├── gh-pages
# │   │               └── master
# │   ├── objects/
# │   │   ├── 01/
# │   │   │   └── 9376f25de9105341d24dd3970b1ce33732203b
# │   │   ├── 03/
# │   │   │   └── f0a97f22f2b58edffa88f58bf2e6fa69fb8ad3
# │   │   ├── 07/
# │   │   │   ├── 6eeb29d4830a99990931eb0914a9fbb5713b73
# │   │   │   └── c14fffcb794a453a5398ece4360f9c3c44438f
# │   │   ├── 09/
# │   │   │   └── 8f9f542de2ca57b92f59cae3b6f8f829288881
# │   │   ├── 0d/
# │   │   │   └── 623483ffdf5f9f96900108042a7ab0643fe2a3
# │   │   ├── 0e/
# │   │   │   ├── 67152ee52012cd966b0730aec9e5f920e82d45
# │   │   │   └── d5669fc0ea67dab1899bb70d80f43b11e57a7d
# │   │   ├── 0f/
# │   │   │   ├── 2f2540ef0ac94f5d13999f57b12dfcdda90bfa
# │   │   │   └── c78353c2abb5fe273376794147e3e6a0f8ac11
# │   │   ├── 10/
# │   │   │   ├── 3228eb3dfe93c1bd0ef798b01b35d6305e5c44
# │   │   │   └── d6536dfa3c80a640a415f0438002f37879ee1c
# │   │   ├── 12/
# │   │   │   └── 6e7ea880a4e7924201bb09570d912e8e44f4c5
# │   │   ├── 14/
# │   │   │   └── 249384e0e5b1c8745d7d57572bdb1007e98ae7
# │   │   ├── 16/
# │   │   │   ├── 0c44d5cc842bab321069990085268a19fccb4e
# │   │   │   ├── 289500a33b8672ab67b49457f9509b85d63409
# │   │   │   ├── c64926a6b6b0fc60396a0259999f4d3b6ee0b1
# │   │   │   └── db8fb3dcb143a3aebf95fa1676fe0b4cd021a8
# │   │   ├── 18/
# │   │   │   ├── 054cc36a4d91f738fa4d8533899da08050f442
# │   │   │   └── 40c283abf4ab1c8c45734827bc8d5943d48b1f
# │   │   ├── 19/
# │   │   │   ├── d3244426639d528709023fe2569396151f1ef0
# │   │   │   └── f07d4d2602de9309769cc1d3f3a67ae50ce0a5
# │   │   ├── 1a/
# │   │   │   └── 0cc8daf9b544b69d45c86e1ce8273601e4b400
# │   │   ├── 1c/
# │   │   │   └── a70b19c5675cef530f81f2ea4539a884d07dac
# │   │   ├── 1e/
# │   │   │   └── b29256eba5f18414663b6eaec5d090fdbabaa1
# │   │   ├── 1f/
# │   │   │   ├── bd7ecc7a119e98bb28c4c2166fc9389d2ea086
# │   │   │   └── f5a2b32fe2ef3e9ab7690a4a92aa9114edd605
# │   │   ├── 20/
# │   │   │   └── 7e7f8c35749f6647c90204f98dc86946c28661
# │   │   ├── 21/
# │   │   │   └── 7a89236781a851ec185c478962bf061f110114
# │   │   ├── 22/
# │   │   │   ├── 727a9b951dfb8ca39f8e20754d97f0cce8f25d
# │   │   │   └── f70e9da3cd1e41e3b2133529a69417a1eae05f
# │   │   ├── 24/
# │   │   │   ├── 1ad87abd8af8ad5a1a60380869bb0b1859c023
# │   │   │   ├── 2e9f5f9f2dc4a9e63132e86c909c58cbdd636c
# │   │   │   └── ce15ab7ead32f98c7ac3edcd34bb2010ff4326
# │   │   ├── 26/
# │   │   │   └── ce4eaf13cb081b872c3d7a264003f0f7780ba1
# │   │   ├── 27/
# │   │   │   ├── 15d427fb0e8c3fa13d9f9fe1b7d49c272141ab
# │   │   │   └── ee01b45f8a58e55f2899b94bd0b6b1e9d90c07
# │   │   ├── 28/
# │   │   │   ├── 1605ce1eb3a3c1982a8cd8370161b9bd126fdf
# │   │   │   └── 4ac56218b9abdda0186c2faa692603fe6179ba
# │   │   ├── 2a/
# │   │   │   ├── 0f5c896b3e6fb9ceaea3df27f7ae51ec59ccbc
# │   │   │   ├── 666ce0a24f013ea8583153010527361a972aba
# │   │   │   └── fe444312a0fb66dd4d1fb9cfb207e837777377
# │   │   ├── 2b/
# │   │   │   └── f6dd57b7e00961581be26959f9cf266d96b84e
# │   │   ├── 2e/
# │   │   │   └── b11fc61f529f3fd3cd0171ae7cf8dc27cb1b6f
# │   │   ├── 2f/
# │   │   │   └── 8be94c7f476d87116c15d32c9d2fe04cc299b2
# │   │   ├── 30/
# │   │   │   ├── c14aeb2be63289242bb3cc49891654a672a8ec
# │   │   │   └── cac860ef53ca2e91193634929ecdd4377d8659
# │   │   ├── 31/
# │   │   │   └── fbe7ad699ed7e3cc92071e9b9e0f8ba4e801cf
# │   │   ├── 33/
# │   │   │   ├── 596711d2f618a240373cbf32c339a534265b67
# │   │   │   └── d4fcab57f36f45e67a74cdb511393fba4a5e0e
# │   │   ├── 34/
# │   │   │   └── e6fa8861d0f0b0a14688594371c088870978b6
# │   │   ├── 38/
# │   │   │   ├── 6c784ca3bba5c52a42af694b23cef22534995d
# │   │   │   └── d8da75f15417bcb992ca9bc15c741cbfd37b49
# │   │   ├── 39/
# │   │   │   └── 8f42f088f2d4c9e8a336e815f1555f86eac9c4
# │   │   ├── 3a/
# │   │   │   ├── add53c9e6385ce71767c94ffe90d47f1ec070d
# │   │   │   └── f8215beb13ec190f940451f32ca1df75f8d8a2
# │   │   ├── 3c/
# │   │   │   └── 8d86057515a05de878ee96a4086670c731e29e
# │   │   ├── 3d/
# │   │   │   └── 8f4ddb7038ac84c5d70b779d2b340e411e982e
# │   │   ├── 3e/
# │   │   │   └── aa58aeeb71827fb647cf80c03dc30872c837b6
# │   │   ├── 3f/
# │   │   │   └── f17d807fd8aa003bed8bb2a69e8f0909592fd1
# │   │   ├── 41/
# │   │   │   └── 8149b3e94fc1ee3de7ca6dae75b7b713322f33
# │   │   ├── 44/
# │   │   │   └── b31e53c8923925d296c5ffb7babb8fcfb357b9
# │   │   ├── 45/
# │   │   │   └── 061609da6421f880072e7a690208c9a7b4dcbb
# │   │   ├── 46/
# │   │   │   ├── e5acebd45eeb3b3fd0e49966adbb26b816922c
# │   │   │   └── ed29bc0e26debc0c7705c2b990b0ad18390dc3
# │   │   ├── 48/
# │   │   │   └── 721d301af69969d0760c65ce909dd613bb0a44
# │   │   ├── 49/
# │   │   │   ├── 5a0ffea6cedd33c18cf7098cd8e4eb1067b2bb
# │   │   │   └── a167fd899f9dac01b99f2bd83a448121e85299
# │   │   ├── 4b/
# │   │   │   ├── 5034e9fad283de1106c6b46c28a2eae1abee00
# │   │   │   └── 645d179528da2a5e3a320eabb62da69f3e17bb
# │   │   ├── 4e/
# │   │   │   └── ab53926966c30304fde14361f245ef6fda3a88
# │   │   ├── 4f/
# │   │   │   └── 1ab9195b447e18dacbf914142f997e7637a27f
# │   │   ├── 50/
# │   │   │   ├── 2f96f1b19ccc3a717f4e66e596f195d55f8092
# │   │   │   └── 3e802681b0bcd22a3e3d3a79ffacd742cc0fca
# │   │   ├── 53/
# │   │   │   └── 02b7236fd2a0fc5431ea77f4329619af728c5c
# │   │   ├── 55/
# │   │   │   └── d02fedc09e9f4e4a082b57d45453bf801022b4
# │   │   ├── 56/
# │   │   │   └── 90e9b157fe442bfea19d9761a152c25fb224c1
# │   │   ├── 57/
# │   │   │   └── a586302f43d411b1ac8ecde3ff92d672846e9e
# │   │   ├── 5a/
# │   │   │   └── 26da5ae76178baee3766f7ef036620f93af58f
# │   │   ├── 5c/
# │   │   │   ├── 14b3483e64a358449c8b9fc94149d39ee504dc
# │   │   │   ├── 1b0fb642a0dd65aa9c07407f0b511c9c74151b
# │   │   │   ├── 1da71ec83746da3c6d74744184580208ea0101
# │   │   │   ├── c24a27560146bbb5578697e79bf94c4311f963
# │   │   │   └── e619cbbc70c64c374d98bf7d00b125662e08c8
# │   │   ├── 5e/
# │   │   │   ├── 2b2528c7697aeb4a433cd87009339c9101c224
# │   │   │   └── 9a8032b666f86eeb76c88c090c1706197b338d
# │   │   ├── 60/
# │   │   │   ├── 73c5306107337c77ebdef7212bc159343eaa9d
# │   │   │   └── cd94e05c8ccb6eee73d6539d06f26572c719e3
# │   │   ├── 61/
# │   │   │   └── 71e41f13e1f0aa152a0d6dc0699bccc05e40db
# │   │   ├── 62/
# │   │   │   └── 91fec84a7c6cb3756a662eb6da7f3da7181ecf
# │   │   ├── 63/
# │   │   │   └── edbcf612ab1a33b40f02a3c59c1b05aac1a29c
# │   │   ├── 64/
# │   │   │   └── 6d56968e86ccec0d8f4fd36ac80f80ded6d262
# │   │   ├── 65/
# │   │   │   └── 9db465b881076c20fd92852b0f60b27b48ae7b
# │   │   ├── 66/
# │   │   │   └── 6375d9765c857de7bcd45f65a489fb8a70e14c
# │   │   ├── 67/
# │   │   │   ├── 04f2832292346bd4d680765c470270a5812f2b
# │   │   │   └── 312f2ab52d64af6fd5d240f9c05488e63b1ddd
# │   │   ├── 6a/
# │   │   │   ├── 450ab73370ea6c52130fcc87e33aac90bef7f6
# │   │   │   └── d4d2be9fe8a93f75c8772fa72d2faa7de4b2f1
# │   │   ├── 6c/
# │   │   │   └── 46ef31a6a6a1cc293639576a706a5cbd6836e0
# │   │   ├── 6d/
# │   │   │   ├── 9c36f1357662f3a41fab28654f07013908ede9
# │   │   │   └── faa34e158ed6a5b9418ce62095de2562c5214a
# │   │   ├── 6f/
# │   │   │   ├── 7659eadc297b46d0458006c481ad5f6864dcde
# │   │   │   ├── 97c7e12ff8e5775eeecf7cadccaf35291ec717
# │   │   │   ├── f3596bf45166554a0b8b61fd670eb4b41e3689
# │   │   │   └── f7d271ff82639e0bbe07735e0a01d9ad3d69de
# │   │   ├── 70/
# │   │   │   └── 4d04228e1fa299a19ecaacdaafa8dccfdfb205
# │   │   ├── 71/
# │   │   │   └── c47d92c3a2f67e8756876e3595d064caafabe1
# │   │   ├── 74/
# │   │   │   └── eb6df2b8a144aa9f4b957624fd4c5919e5021d
# │   │   ├── 77/
# │   │   │   └── a8e4713dfc157e8eb01c0b59306c083a3f328e
# │   │   ├── 7a/
# │   │   │   ├── 1506eac9e37e3a79c495cb817de532ee73c4b4
# │   │   │   └── 606ac1c3f4b323b52db6d2ef2ec7095bd6c247
# │   │   ├── 7c/
# │   │   │   ├── 0ade2f5fc9154e773187d906e9a4d78625eda7
# │   │   │   ├── b316786474e3ffbe58336ea6eaf76be42a7896
# │   │   │   └── b484a30ad39c7a037affc70cc315880c7d98d5
# │   │   ├── 7e/
# │   │   │   └── 16baf3256997c02fca4a8225f8cc90da602340
# │   │   ├── 7f/
# │   │   │   └── 48b6fdc779e9d3e6ece996262d0cf85835cfd7
# │   │   ├── 80/
# │   │   │   └── 18ed1dc0bc11662dbc6a587c04e141004100f9
# │   │   ├── 83/
# │   │   │   ├── 27bd611361eca695b02be5c00b4fda312e192a
# │   │   │   └── a602a3a5a1dce076a4e51af784b9cfbb69a1f3
# │   │   ├── 84/
# │   │   │   ├── 34b3bdae39b9c0619d4f1e6d23e3636f58ee8e
# │   │   │   └── da6526bcd6cc0060c868444472f89bc8e1b3af
# │   │   ├── 86/
# │   │   │   ├── 01141cbb1cd8a847a437c1267d13d88f1b8d47
# │   │   │   └── e49bee282a49eb80ac6c57580f3b55fbe5e9ee
# │   │   ├── 87/
# │   │   │   ├── 1d361a2a654e168485273848ace271194ef6b4
# │   │   │   ├── 1f89c568de09b418a2bbf3f913174075e6f485
# │   │   │   └── 8749cc8857f6632c97e4bd6aa1bcdc4e1dc71f
# │   │   ├── 89/
# │   │   │   ├── 4778f2fa8d3adbba1e3c23557be3c7cd9989d3
# │   │   │   └── 583ee691eea1968263a31567218fc34c34cda6
# │   │   ├── 8a/
# │   │   │   └── ef26dddb0718325defad8a3e16eb2153e6b1a1
# │   │   ├── 8b/
# │   │   │   └── 6186cabba0ca128a41723ceb781563828430d9
# │   │   ├── 8d/
# │   │   │   └── d858d3a6c18617f8297ef7deb840fb7d17b749
# │   │   ├── 8e/
# │   │   │   └── c1b7759fb59f62d6e9adf728a27a046bad7c66
# │   │   ├── 91/
# │   │   │   ├── 5607e839907b1c497e0c13941b2cb5723f32a3
# │   │   │   └── d80c439dffaa69dd4dce58e3ccc69e5feb9a6a
# │   │   ├── 92/
# │   │   │   └── 11b0d4e8a27ad22b61a9daa9133d9a30706226
# │   │   ├── 93/
# │   │   │   ├── 33f007f8bd039c59fe4a9136ccf3d61a816a1a
# │   │   │   ├── 56938de62f58b9d675c4516c78e4e9632d93a4
# │   │   │   └── ec80085f819a08ab982e15078332b5b5db396c
# │   │   ├── 94/
# │   │   │   └── 7bc662b8cfa118a8db8f0264d44de7301369f8
# │   │   ├── 98/
# │   │   │   ├── 1d046f21b5200b67c96965df1eeeec86ef8bcf
# │   │   │   └── 8ccb782cbd04db2898ce16f8cadb294579a2f2
# │   │   ├── 99/
# │   │   │   └── 4e5091ce5ab462d33c3fa5ff7125e7784fb579
# │   │   ├── 9b/
# │   │   │   └── 1e6337c9299a700401a2a78a2c6ffced475216
# │   │   ├── 9d/
# │   │   │   ├── 275af070d772a84f2b706e1cecf456e2436b06
# │   │   │   ├── 4e302dd3f13babd359b98579f526d36b4da5ae
# │   │   │   └── f899a2b797f2a86189321eb6abd429d475b042
# │   │   ├── 9e/
# │   │   │   └── 868a71e05cc236c95b6577922dfc22b21cfe0c
# │   │   ├── 9f/
# │   │   │   └── 421f013ceb0ceb3bcf9e90510b815b3e4603a2
# │   │   ├── a0/
# │   │   │   ├── 174485b5965b281eec1b09956a384792d608f0
# │   │   │   └── 26942e2dfe809c2c2d2c6140dadf0ffe0fe0e9
# │   │   ├── a3/
# │   │   │   └── 8f6582c773be7b4ad64c194b1adca15fe2762b
# │   │   ├── a4/
# │   │   │   ├── 0dd82b8debaaeb83b985555155243e14f001f9
# │   │   │   ├── 10cb06f2c25c8e89bb7a63b8de134b500ffe03
# │   │   │   └── 7766569ab9614c5d66dd583308adf3da3ce051
# │   │   ├── a5/
# │   │   │   └── 19619d76f1393f2ace7935c74d7728754e444b
# │   │   ├── a7/
# │   │   │   └── 5eeb543a97e274ed393bedeee0e0ecae639001
# │   │   ├── a9/
# │   │   │   └── 0ff8f38eec395386ef4860ca314f26628149d6
# │   │   ├── ab/
# │   │   │   └── 72da61195f1bf5e8b505676c8aabe7c7d44de3
# │   │   ├── ac/
# │   │   │   └── 023576dde5a52dadd901934dce76a8ad8ffb09
# │   │   ├── ae/
# │   │   │   └── feae320490291e560fc00e7c7335dc6ea5fde8
# │   │   ├── af/
# │   │   │   ├── 38bffa846941412d585b11a1ddca623aa8380a
# │   │   │   ├── acda50493d8ee1f87b79e0d3bc6241e3257aa7
# │   │   │   ├── dc21c8f66760025801441dc9693c24841b6139
# │   │   │   └── ec9527d8340c59d6903c29f59f66612a1bbde0
# │   │   ├── b2/
# │   │   │   └── e9505d2edba5d59822946cb332ebc917c2137d
# │   │   ├── b3/
# │   │   │   └── 47fd0dc11de34affcab2584a068bc08c713d44
# │   │   ├── b4/
# │   │   │   ├── a2bf8a9b0370cae111fabb63a3c47e451d0937
# │   │   │   └── d955ff36beafb8626f0f8d3118d8c8552d858d
# │   │   ├── b5/
# │   │   │   └── d2471dbc0b3a1508913b79756434dead7cba15
# │   │   ├── b6/
# │   │   │   ├── 30c283f91e29588215743bf3d73f6d2d802f6d
# │   │   │   └── eeb48315b34984c2294d016da71d4e2acb1d1c
# │   │   ├── b7/
# │   │   │   ├── 587218443e4e89b829c2147ab74edea1a8f1bf
# │   │   │   └── e4ae08e67346d55db5d821657023f44b676d75
# │   │   ├── b8/
# │   │   │   └── 443b2908f09756875bc9bcd47aa3265be9b23f
# │   │   ├── b9/
# │   │   │   └── db1ebd19e0f6821d918a277c7b43e680323184
# │   │   ├── ba/
# │   │   │   └── c7071ac6b0c45f01b9d8ed6a56acd87310c49f
# │   │   ├── bb/
# │   │   │   └── de11ed9bf3df9ce42aad9c2149f1e7e8576ad1
# │   │   ├── bd/
# │   │   │   └── 4a82c688737edcd6a5753673a6b4d69bb000b9
# │   │   ├── be/
# │   │   │   ├── 8574b5aaffdac92230e980a7e3b7db1151529f
# │   │   │   ├── 981a0141423e91d2a2d1d86b264e5f8b393baf
# │   │   │   └── ca0ad32a06acba0d346a950592ce65e7dffd59
# │   │   ├── c0/
# │   │   │   └── 4d3b0fc4631f6678b29903db836e177532f689
# │   │   ├── c1/
# │   │   │   └── 636f92c2b9df63b048dc6a7116547a4da90ed2
# │   │   ├── c3/
# │   │   │   └── b5f06e0b43ab57a20b19899a7c5632dcf81e89
# │   │   ├── c4/
# │   │   │   └── 016212e60eaf40210225ecca18530e339f40fa
# │   │   ├── c6/
# │   │   │   ├── 1ff82ee76ffaf68c2b779c82fdf7c03f29bd52
# │   │   │   └── 6904dfaff6c8d7b91ee06bb5d81859a6d71c44
# │   │   ├── c7/
# │   │   │   ├── 301076e247d0fba49cc37b030e68476a2f6233
# │   │   │   └── 6c8bb9744f06457aa6142acf967a608d7631b2
# │   │   ├── c8/
# │   │   │   └── 29d2daef4691197b69eb88f3a62e86a349f0e8
# │   │   ├── cb/
# │   │   │   ├── c0d2b8df275de50e81ebc9a0565318491181a5
# │   │   │   └── f2cc361807f9838949d019bc969c6dffe81027
# │   │   ├── ce/
# │   │   │   └── 9dd9f533cb5486d6941844f442b59d4a9e9175
# │   │   ├── d0/
# │   │   │   └── adb4ebeebfcf8d125a687b6f89cd103922bfb9
# │   │   ├── d1/
# │   │   │   ├── 7e65321ded787f8a5deb59c00df0df7d0e8982
# │   │   │   └── f81cdee2a3fd93f9c055e541e9ecd73730cae5
# │   │   ├── d2/
# │   │   │   └── 42c7d88cca89a611d44041baac00cc17399902
# │   │   ├── d4/
# │   │   │   └── 9cdcb9ee593dcf50927dbd05c35421ecd4b2e5
# │   │   ├── d7/
# │   │   │   ├── 28670226eb9bbe41d718e74f10ee538016667f
# │   │   │   └── 55e18c750d11465beb2849f8e6b98de33b7a2f
# │   │   ├── d8/
# │   │   │   ├── 01bb03cb4b0d909722edd60ec248aa12bb6221
# │   │   │   └── 50610050331bc9e5a247af034e8c9c6e807000
# │   │   ├── d9/
# │   │   │   ├── 122992b3fc7deb5c55a665663294af47373198
# │   │   │   ├── 17c413ed2e7fe7a0829c6f68c5de379e602b1d
# │   │   │   └── 800b9adaed1f581240b5f8464e650c3d19adc9
# │   │   ├── da/
# │   │   │   └── 124e128e76986181065bb6cb7a773d88d3b10e
# │   │   ├── db/
# │   │   │   └── 0fd2a5b4ea053bc5ce263dc2e3576ea2822404
# │   │   ├── dd/
# │   │   │   ├── 9af9aa7e183ada1e2b577f65c855da8f4944ff
# │   │   │   ├── a93bc920628fa73c20e84b9eb4f1cf67b25bc6
# │   │   │   └── f3382e374f72c4082cd717c64242a1f88af7b9
# │   │   ├── de/
# │   │   │   ├── 0ec942d63cf5737931785cd8785de0763a66ae
# │   │   │   └── 30c72611d8ea7dc815ba580263badba780aee9
# │   │   ├── df/
# │   │   │   ├── 7583cf03114b180a548a44d0391d7732623c5e
# │   │   │   ├── a70f32d1a5947d0d3900d62ee1288802bfecb4
# │   │   │   └── e0770424b2a19faf507a501ebfc23be8f54e7b
# │   │   ├── e0/
# │   │   │   ├── d926cb87a7c0610fa98ca794bbc01c8893024d
# │   │   │   └── fda7b25d4385b370871238ae049d70f55c61c7
# │   │   ├── e1/
# │   │   │   ├── 11b129bc47824af648b436d4bd5321ca2f94d6
# │   │   │   └── fa4f0079337568bbfd0982d896496fe8153824
# │   │   ├── e2/
# │   │   │   ├── a1cca17b7804785f3d0c30ba4aa80aa41a050c
# │   │   │   └── b0e900972fc51435e1fc5f2eb650985317396b
# │   │   ├── e4/
# │   │   │   └── 3b0f988953ae3a84b00331d0ccf5f7d51cb3cf
# │   │   ├── e5/
# │   │   │   └── c0f2816330ab324f2944c1114df8597c8a88b4
# │   │   ├── e6/
# │   │   │   ├── 9de29bb2d1d6434b8b29ae775ad8c2e48c5391
# │   │   │   └── cfd44e5df6e27c026ca0735227eac6ad5a13cc
# │   │   ├── e7/
# │   │   │   ├── 3cd30336cadcbc15c3b22d620470329537c1c1
# │   │   │   └── 7e0f1054fe35c6cfa089106de89f020de41598
# │   │   ├── e8/
# │   │   │   └── 8d60063d911906c9e287dc1925949f53049f11
# │   │   ├── e9/
# │   │   │   └── 265d85ea4aff32eb87c127dd142e95f109c082
# │   │   ├── eb/
# │   │   │   ├── 304e25745e93f128bffaedb6ec00664fe39d28
# │   │   │   ├── 744124ed292743c34820c1801ada57fc4e55fa
# │   │   │   └── cef4f63015c1e26b8784a44849c46d3e675d87
# │   │   ├── ed/
# │   │   │   ├── 74f608c656f8ed96ac8919be0fd668b9766b18
# │   │   │   ├── 83f87f7abb85dc87b049666d7d636925597ff9
# │   │   │   └── d41a9041f6de0c4af314aebe2dcb4ccf8ca3a3
# │   │   ├── ee/
# │   │   │   └── bcbf2b0294a6142b74f81be3a6224631d76cae
# │   │   ├── f1/
# │   │   │   └── 13496d1d29e52d295934a6952f1c0911683f55
# │   │   ├── f3/
# │   │   │   ├── 17696a6000416a0d0cf12b1bd4a88650ee0172
# │   │   │   └── 5c691c0c9a4e71d52556e85c8c31640434641a
# │   │   ├── f5/
# │   │   │   ├── 09374dc599272f6440bf3269e35229eaa48d6e
# │   │   │   └── 16789c9928f261db2827c3d35a2376facd7eee
# │   │   ├── f6/
# │   │   │   └── 364c8fc24fbc4dffd11ff60dfb41b24483311f
# │   │   ├── f8/
# │   │   │   └── 0c1a2ca25d6f10e59bef95565b8c57752db615
# │   │   ├── f9/
# │   │   │   ├── 1b34e0ed7c0a977350b09278d89d19d46b9c3f
# │   │   │   └── b168865471773a771da925e9afdd8578bf32e2
# │   │   ├── fa/
# │   │   │   ├── 47e95f57e543368ff6f1efdb1d4a22a63465ac
# │   │   │   ├── 4a0dccdcd1c9bbb9a3956e2c80828b3a160ddc
# │   │   │   └── 7cbe1bb4565615de9f031190ed45bb2c8ec1c2
# │   │   ├── fb/
# │   │   │   ├── 76bb3b70c7002f28022e175c29849a2029dbbf
# │   │   │   └── 9f038aa956f1b377e8b47d4bb14caf76647fa9
# │   │   ├── fc/
# │   │   │   └── 24e7a62dc288c776f8448cd073a01e7721ed32
# │   │   ├── fd/
# │   │   │   └── 7e067c2618856f860fce03d66311deed31e70a
# │   │   ├── fe/
# │   │   │   ├── c04e477e17e5ff8c0e303094fda302f97f1f64
# │   │   │   └── d038668dae9e8b3bf68e5e133a48ca4ce8c206
# │   │   ├── info/
# │   │   └── pack/
# │   ├── ORIG_HEAD
# │   └── refs/
# │       ├── heads/
# │       │   └── master
# │       ├── remotes/
# │       │   └── origin/
# │       │       ├── gh-pages
# │       │       └── master
# │       └── tags/
# ├── .gitattributes
# ├── .ipynb_checkpoints/
# │   └── Respo_folder_tree-checkpoint.ipynb
# ├── 3D Printer Codes/
# │   ├── .gitattributes
# │   ├── BG2.stl
# │   ├── BG4.stl
# │   ├── BG5.gcode
# │   ├── BG5.stl
# │   ├── BG7.gcode
# │   ├── C1.1.gcode
# │   ├── C1.1.stl
# │   ├── C1.2.gcode
# │   ├── C1.2.stl
# │   ├── Capture.PNG
# │   ├── cuuter worn part.gcode
# │   └── IMG_20180713_183558.jpg
# ├── Assets/
# │   └── Warehouse-LEAD-IMAGE.jpeg
# ├── Big Data Coding/
# │   ├── Chunking-Big-Data-master/
# │   │   ├── .gitattributes
# │   │   └── chunking Big Data.R
# │   └── Read-and-Process-Files-Larger-Than-RAM-master/
# ├── C Codes/
# │   └── classes_in_cpp-master/
# │       ├── .gitattributes
# │       └── Amin1th/
# │           ├── Amin1th.cbp
# │           ├── Amin1th.depend
# │           ├── Amin1th.layout
# │           ├── main.cpp
# │           └── obj/
# │               └── Debug/
# │                   └── main.o
# ├── Mathematica Ploting/
# │   ├── .gitattributes
# │   └── Untitled-3.nb
# ├── Metahurestic Algorithms and Projects/
# │   ├── DE-Algorithm-master/
# │   │   ├── .gitattributes
# │   │   ├── DE algorithm.R
# │   │   ├── DEalgorithmForModeling.m
# │   │   ├── funcparameters.m
# │   │   ├── matlab.mat
# │   │   └── n.m
# │   ├── Differential-Evolution-Algorithm-master/
# │   │   ├── .gitattributes
# │   │   ├── matlab.mat
# │   │   ├── README.md
# │   │   ├── sam2.m
# │   │   └── saman.m
# │   ├── DPSO-master/
# │   │   ├── .gitattributes
# │   │   ├── amin.mat
# │   │   ├── ase123.m
# │   │   ├── Best answer for 50 well +.txt
# │   │   ├── candidates and etc.xlsx
# │   │   ├── DayCalc.asv
# │   │   ├── DayCalc.m
# │   │   ├── DayCalc2.asv
# │   │   ├── DayCalc2.m
# │   │   ├── DIV.asv
# │   │   ├── DIV.m
# │   │   ├── GC.asv
# │   │   ├── GC.m
# │   │   ├── TM.asv
# │   │   ├── TM.m
# │   │   ├── Untitled.asv
# │   │   ├── Untitled3.asv
# │   │   ├── V.mat
# │   │   ├── well plot.m
# │   │   ├── WellLandScapes.mat
# │   │   ├── WellProductionPowers.mat
# │   │   ├── WLSC.asv
# │   │   └── WLSC.m
# │   ├── GA-master/
# │   │   ├── .gitattributes
# │   │   ├── GAINEXCEL-20(a12).txt
# │   │   └── GAINEXCEL-20(a12).xlsm
# │   └── PSO-Algorithm-master/
# │       ├── MATLAB code/
# │       │   ├── Meta Optimization codes.txt
# │       │   └── PSO codes.txt
# │       └── PSONEWALGORITHMCODES.m
# ├── Parallel computing and OOP used in Drilling Project/
# │   ├── .DS_Store
# │   ├── Drilling OOP-master/
# │   │   ├── .DS_Store
# │   │   ├── .gitattributes
# │   │   ├── curvefit-gh-allcases-dea-oop.ipynb
# │   │   └── README.md
# │   └── HydraulicProgram-master/
# │       ├── .gitattributes
# │       ├── Hydraulic Program designed by Atashnezahd.xlsm
# │       └── MacroInExcel
# ├── README.md
# ├── Respo_folder_tree.ipynb
# └── Side Projects/
#     └── AR_VR_appForAndroid-master/
#         ├── .gitattributes
#         ├── ARGen5.apk
#         ├── IMG_20180528_160644.jpg
#         ├── pics.rar
#         └── scenes.rar
